# %% [markdown]
# # Importing dataset and libraries

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import random

# %%
lemmatizer = WordNetLemmatizer()
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# # Pre-Processing

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
classes
# Out:
# ['greeting',
#  'goodbye',
#  'thanks',
#  'options',
#  'adverse_drug',
#  'blood_pressure',
#  'blood_pressure_search',
#  'pharmacy_search',
#  'hospital_search']

# %%
words
# Out:
# ['Hi',
#  'there',
#  'How',
#  'are',
#  'you',
#  'Is',
#  'anyone',
#  'there',
#  '?',
#  'Hey',
#  'Hola',
#  'Hello',
#  'Good',
#  'day',
#  'Bye',
#  'See',
#  'you',
#  'later',
#  'Goodbye',
#  'Nice',
#  'chatting',
#  'to',
#  'you',
#  ',',
#  'bye',
#  'Till',
#  'next',
#  'time',
#  'Thanks',
#  'Thank',
#  'you',
#  'That',
#  "'s",
#  'helpful',
#  'Awesome',
#  ',',
#  'thanks',
#  'Thanks',
#  'for',
#  'helping',
#  'me',
#  'How',
#  'you',
#  'could',
#  'help',
#  'me',
#  '?',
#  'What',
#  'you',
#  'can',
#  'do',
#  '?',
#  'What',
#  'help',
#  'you',
#  'provide',
#  '?',
#  'How',
#  'you',
#  'can',
#  'be',
#  'helpful',
#  '?',
#  'What',
#  'support',
#  'is',
#  'offered',
#  'How',
#  'to',
#  'check',
#  'Adverse',
#  'drug',
#  'reaction',
#  '?',
#  'Open',
#  'adverse',
#  'drugs',
#  'module',
#  'Give',
#  'me',
#  'a',
#  'list',
#  'of',
#  'drugs',
#  'causing',
#  'adverse',
#  'behavior',
#  'List',
#  'all',
#  'drugs',
#  'suitable',
#  'for',
#  'patient',
#  'with',
#  'adverse',
#  'reaction',
#  'Which',
#  'drugs',
#  'dont',
#  'have',
#  'adverse',
#  'reaction',
#  '?',
#  'Open',
#  'blood',
#  'pressure',
#  'module',
#  'Task',
#  'related',
#  'to',
#  'blood',
#  'pressure',
#  'Blood',
#  'pressure',
#  'data',
#  'entry',
#  'I',
#  'want',
#  'to',
#  'log',
#  'blood',
#  'pressure',
#  'results',
#  'Blood',
#  'pressure',
#  'data',
#  'management',
#  'I',
#  'want',
#  'to',
#  'search',
#  'for',
#  'blood',
#  'pressure',
#  'result',
#  'history',
#  'Blood',
#  'pressure',
#  'for',
#  'patient',
#  'Load',
#  'patient',
#  'blood',
#  'pressure',
#  'result',
#  'Show',
#  'blood',
#  'pressure',
#  'results',
#  'for',
#  'patient',
#  'Find',
#  'blood',
#  'pressure',
#  'results',
#  'by',
#  'ID',
#  'Find',
#  'me',
#  'a',
#  'pharmacy',
#  'Find',
#  'pharmacy',
#  'List',
#  'of',
#  'pharmacies',
#  'nearby',
#  'Locate',
#  'pharmacy',
#  'Search',
#  'pharmacy',
#  'Lookup',
#  'for',
#  'hospital',
#  'Searching',
#  'for',
#  'hospital',
#  'to',
#  'transfer',
#  'patient',
#  'I',
#  'want',
#  'to',
#  'search',
#  'hospital',
#  'data',
#  'Hospital',
#  'lookup',
#  'for',
#  'patient',
#  'Looking',
#  'up',
#  'hospital',
#  'details']

# %% [markdown]
# - words have many duplicates and ? ! symbols, we will remove it and do similar for classes

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
words
# Out:
# ["'s",
#  ',',
#  'a',
#  'adverse',
#  'all',
#  'anyone',
#  'are',
#  'awesome',
#  'be',
#  'behavior',
#  'blood',
#  'by',
#  'bye',
#  'can',
#  'causing',
#  'chatting',
#  'check',
#  'could',
#  'data',
#  'day',
#  'detail',
#  'do',
#  'dont',
#  'drug',
#  'entry',
#  'find',
#  'for',
#  'give',
#  'good',
#  'goodbye',
#  'have',
#  'hello',
#  'help',
#  'helpful',
#  'helping',
#  'hey',
#  'hi',
#  'history',
#  'hola',
#  'hospital',
#  'how',
#  'i',
#  'id',
#  'is',
#  'later',
#  'list',
#  'load',
#  'locate',
#  'log',
#  'looking',
#  'lookup',
#  'management',
#  'me',
#  'module',
#  'nearby',
#  'next',
#  'nice',
#  'of',
#  'offered',
#  'open',
#  'patient',
#  'pharmacy',
#  'pressure',
#  'provide',
#  'reaction',
#  'related',
#  'result',
#  'search',
#  'searching',
#  'see',
#  'show',
#  'suitable',
#  'support',
#  'task',
#  'thank',
#  'thanks',
#  'that',
#  'there',
#  'till',
#  'time',
#  'to',
#  'transfer',
#  'up',
#  'want',
#  'what',
#  'which',
#  'with',
#  'you']

# %%
# sort classes
classes = sorted(list(set(classes)))
classes
# Out:
# ['adverse_drug',
#  'blood_pressure',
#  'blood_pressure_search',
#  'goodbye',
#  'greeting',
#  'hospital_search',
#  'options',
#  'pharmacy_search',
#  'thanks']

# %%
documents
# Out:
# [(['Hi', 'there'], 'greeting'),
#  (['How', 'are', 'you'], 'greeting'),
#  (['Is', 'anyone', 'there', '?'], 'greeting'),
#  (['Hey'], 'greeting'),
#  (['Hola'], 'greeting'),
#  (['Hello'], 'greeting'),
#  (['Good', 'day'], 'greeting'),
#  (['Bye'], 'goodbye'),
#  (['See', 'you', 'later'], 'goodbye'),
#  (['Goodbye'], 'goodbye'),
#  (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'),
#  (['Till', 'next', 'time'], 'goodbye'),
#  (['Thanks'], 'thanks'),
#  (['Thank', 'you'], 'thanks'),
#  (['That', "'s", 'helpful'], 'thanks'),
#  (['Awesome', ',', 'thanks'], 'thanks'),
#  (['Thanks', 'for', 'helping', 'me'], 'thanks'),
#  (['How', 'you', 'could', 'help', 'me', '?'], 'options'),
#  (['What', 'you', 'can', 'do', '?'], 'options'),
#  (['What', 'help', 'you', 'provide', '?'], 'options'),
#  (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'),
#  (['What', 'support', 'is', 'offered'], 'options'),
#  (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'),
#  (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'),
#  (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'],
#   'adverse_drug'),
#  (['List',
#    'all',
#    'drugs',
#    'suitable',
#    'for',
#    'patient',
#    'with',
#    'adverse',
#    'reaction'],
#   'adverse_drug'),
#  (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'],
#   'adverse_drug'),
#  (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'),
#  (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'),
#  (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'),
#  (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'],
#   'blood_pressure'),
#  (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'),
#  (['I',
#    'want',
#    'to',
#    'search',
#    'for',
#    'blood',
#    'pressure',
#    'result',
#    'history'],
#   'blood_pressure_search'),
#  (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'),
#  (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'),
#  (['Show', 'blood', 'pressure', 'results', 'for', 'patient'],
#   'blood_pressure_search'),
#  (['Find', 'blood', 'pressure', 'results', 'by', 'ID'],
#   'blood_pressure_search'),
#  (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'),
#  (['Find', 'pharmacy'], 'pharmacy_search'),
#  (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'),
#  (['Locate', 'pharmacy'], 'pharmacy_search'),
#  (['Search', 'pharmacy'], 'pharmacy_search'),
#  (['Lookup', 'for', 'hospital'], 'hospital_search'),
#  (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'],
#   'hospital_search'),
#  (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'),
#  (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'),
#  (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# documents = combination between patterns and intents
print (len(documents), "documents\n")

# classes = intents
print (len(classes), "classes", classes, "\n")

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# 47 documents
#
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
#
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# # Pickle

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %% [markdown]
# # Training data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)

# %%
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# %%
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# Out:
# C:\Users\Anuj\AppData\Local\Temp/ipykernel_3472/3232993347.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
from tensorflow.keras.optimizers import Adam

# %%
len(train_y[0])
# Out:
# 9

# %%
(len(train_x[0]),)
# Out:
# (88,)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
adm = Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adm, metrics=['accuracy'])

# %%
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2259 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9537 - accuracy: 0.3404
# Epoch 3/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4434 - accuracy: 0.5745
# Epoch 4/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0413 - accuracy: 0.6809
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7268 - accuracy: 0.7447
# Epoch 6/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5034 - accuracy: 0.8511
# Epoch 7/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4956 - accuracy: 0.8298
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.9574
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8723
# Epoch 10/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2253 - accuracy: 0.9574
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2930 - accuracy: 0.8936
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9787
# Epoch 13/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.8936
# Epoch 14/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0918 - accuracy: 0.9787
# Epoch 15/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9362
# Epoch 16/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0568 - accuracy: 0.9787
# Epoch 17/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2703 - accuracy: 0.9362
# Epoch 18/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.2189 - accuracy: 0.9149
# Epoch 19/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0900 - accuracy: 0.9787
# Epoch 20/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0526 - accuracy: 0.9787
# Epoch 21/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9787
# Epoch 22/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9362
# Epoch 23/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 24/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 26/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0308 - accuracy: 0.9787
# Epoch 27/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 28/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.9149
# Epoch 30/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.1732 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 32/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1611 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0340 - accuracy: 0.9787
# Epoch 34/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0907 - accuracy: 0.9574
# Epoch 35/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0282 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1599 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.1057 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 39/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1767 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.1729 - accuracy: 0.9149
# Epoch 42/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 43/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1149 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1672 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 49/200
# 10/10 [==============================] - 0s 996us/step - loss: 0.0998 - accuracy: 0.9362
# Epoch 50/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.1425 - accuracy: 0.9362
# Epoch 52/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 890us/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0689 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0608 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0407 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0186 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 885us/step - loss: 0.0281 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 996us/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 997us/step - loss: 5.2039e-04 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0998 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 886us/step - loss: 9.7354e-05 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0190 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 996us/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9574
# Epoch 78/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.3276 - accuracy: 0.9362
# Epoch 79/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0767 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.3347 - accuracy: 0.9362
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9574
# Epoch 84/200
# 10/10 [==============================] - 0s 997us/step - loss: 2.6643e-04 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0329 - accuracy: 0.9787
# Epoch 86/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9574
# Epoch 87/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.2632 - accuracy: 0.9574
# Epoch 89/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0638 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0533 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0678 - accuracy: 0.9574
# Epoch 96/200
# 10/10 [==============================] - 0s 884us/step - loss: 0.1160 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0491 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9362
# Epoch 99/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0651 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1560 - accuracy: 0.9574
# Epoch 101/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.2903 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0537 - accuracy: 0.9574
# Epoch 105/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.1277 - accuracy: 0.9574
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.2655 - accuracy: 0.9362
# Epoch 111/200
# 10/10 [==============================] - 0s 774us/step - loss: 0.2103 - accuracy: 0.9362
# Epoch 112/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0334 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9787
# Epoch 114/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.1472 - accuracy: 0.9362
# Epoch 115/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.2140 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.3078 - accuracy: 0.9574
# Epoch 118/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.1769 - accuracy: 0.9362
# Epoch 121/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0289 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 125/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0323 - accuracy: 0.9787
# Epoch 127/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0353 - accuracy: 0.9787
# Epoch 128/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9574
# Epoch 129/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0427 - accuracy: 0.9787
# Epoch 130/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1449 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0936 - accuracy: 0.9574
# Epoch 132/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1458 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.1062 - accuracy: 0.9574
# Epoch 134/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.1221 - accuracy: 0.9574
# Epoch 135/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0685 - accuracy: 0.9574
# Epoch 137/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3616 - accuracy: 0.9362
# Epoch 138/200
# 10/10 [==============================] - 0s 1ms/step - loss: 3.1455e-04 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.5394 - accuracy: 0.9574
# Epoch 141/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0346 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0442 - accuracy: 0.9574
# Epoch 144/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1283 - accuracy: 0.9574
# Epoch 145/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1507 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0507 - accuracy: 0.9787
# Epoch 147/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.7919 - accuracy: 0.9362
# Epoch 149/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1560 - accuracy: 0.9362
# Epoch 151/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1263 - accuracy: 0.9787
# Epoch 152/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.2745 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1341 - accuracy: 0.9787
# Epoch 155/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0485 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 885us/step - loss: 0.1332 - accuracy: 0.9574
# Epoch 157/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.3217 - accuracy: 0.9149
# Epoch 158/200
# 10/10 [==============================] - 0s 776us/step - loss: 1.3538e-05 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0646 - accuracy: 0.9787
# Epoch 160/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1379 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.9362
# Epoch 162/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1295 - accuracy: 0.9787
# Epoch 164/200
# 10/10 [==============================] - 0s 997us/step - loss: 4.6590e-06 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 887us/step - loss: 1.2286e-05 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0248 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0535 - accuracy: 0.9787
# Epoch 171/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.2029 - accuracy: 0.9149
# Epoch 172/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.1375 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 0.9787
# Epoch 177/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.0560 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0597 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0502 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.5300 - accuracy: 0.9574
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.9574
# Epoch 182/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.2482 - accuracy: 0.9787
# Epoch 183/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.5643 - accuracy: 0.9574
# Epoch 184/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8413 - accuracy: 0.9574
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1272 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0908 - accuracy: 0.9574
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.9362
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 4.6296e-05 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.1627 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.2361 - accuracy: 0.9574
# Epoch 191/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.1322 - accuracy: 0.9574
# Epoch 192/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.1189 - accuracy: 0.9574
# Epoch 193/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.5851 - accuracy: 0.9787
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1258 - accuracy: 0.9574
# Epoch 195/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9362
# Epoch 199/200
# 10/10 [==============================] - 0s 776us/step - loss: 3.8996e-04 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0679 - accuracy: 0.9787

# %%
# Train and Test accuracy
scores = model.evaluate(np.array(train_x), np.array(train_y))
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# 2/2 [==============================] - 0s 997us/step - loss: 0.0000e+00 - accuracy: 1.0000
# Training Accuracy: 100.00%

# %%
model.save('chatbot_model.h5', hist)

# %% [markdown]
# # Hyperparameter Tuning

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
from keras.layers import Dense, Activation, LeakyReLU, Dropout
from keras.activations import relu, sigmoid

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import roc_curve

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_inp', min_value=32, max_value=512, step=32),
                               activation=hp.Choice( 'activation', ['tanh', 'relu', 'LeakyReLU', 'elu']),
                               input_shape = (88,)
                          )
              )
    
    for i in range(hp.Int('num_layers', 2, 20)):                 # Number of layers
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,       # Number of neuron, here it is 32-512
                                            step=32),
                               activation=hp.Choice( 'activation', ['tanh', 'relu', 'LeakyReLU', 'elu'])))
                               
        if hp.Boolean("dropout"):
            model.add(layers.Dropout(rate=0.5))
        
    model.add(layers.Dense(9, activation='softmax'))
    
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='HP Tuner')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# units_inp (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# activation (Choice)
# {'default': 'tanh', 'conditions': [], 'values': ['tanh', 'relu', 'LeakyReLU', 'elu'], 'ordered': False}
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# dropout (Boolean)
# {'default': False, 'conditions': []}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(np.array(train_x), np.array(train_y), epochs=5, validation_split=0.2)
# Out:
# Trial 5 Complete [00h 00m 04s]
# val_accuracy: 0.10000000149011612
#
# Best val_accuracy So Far: 0.3333333432674408
# Total elapsed time: 00h 00m 36s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\HP Tuner
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001FBE671FE50>
# Trial summary
# Hyperparameters:
# units_inp: 32
# activation: elu
# num_layers: 15
# units_0: 64
# dropout: False
# units_1: 64
# learning_rate: 0.001
# units_2: 96
# units_3: 288
# units_4: 512
# units_5: 320
# units_6: 288
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# Score: 0.3333333432674408
# Trial summary
# Hyperparameters:
# units_inp: 480
# activation: tanh
# num_layers: 7
# units_0: 448
# dropout: True
# units_1: 352
# learning_rate: 0.001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# Score: 0.26666667064030963
# Trial summary
# Hyperparameters:
# units_inp: 480
# activation: LeakyReLU
# num_layers: 8
# units_0: 288
# dropout: True
# units_1: 288
# learning_rate: 0.01
# units_2: 416
# units_3: 480
# units_4: 192
# units_5: 480
# units_6: 448
# units_7: 224
# units_8: 224
# units_9: 160
# units_10: 160
# units_11: 192
# units_12: 128
# units_13: 320
# units_14: 480
# Score: 0.23333334177732468
# Trial summary
# Hyperparameters:
# units_inp: 416
# activation: LeakyReLU
# num_layers: 6
# units_0: 192
# dropout: False
# units_1: 416
# learning_rate: 0.0001
# units_2: 320
# units_3: 480
# units_4: 32
# units_5: 160
# units_6: 64
# Score: 0.16666666915019354
# Trial summary
# Hyperparameters:
# units_inp: 448
# activation: relu
# num_layers: 7
# units_0: 192
# dropout: True
# units_1: 96
# learning_rate: 0.01
# units_2: 448
# units_3: 448
# units_4: 224
# units_5: 288
# units_6: 160
# units_7: 256
# units_8: 416
# units_9: 288
# units_10: 128
# units_11: 288
# units_12: 224
# units_13: 448
# units_14: 384
# Score: 0.10000000149011612

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                2848
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 96)                6240
# _________________________________________________________________
# dense_4 (Dense)              (None, 288)               27936
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               147968
# _________________________________________________________________
# dense_6 (Dense)              (None, 320)               164160
# _________________________________________________________________
# dense_7 (Dense)              (None, 288)               92448
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                9248
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_16 (Dense)             (None, 9)                 297
# =================================================================
# Total params: 464,809
# Trainable params: 464,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.fit(np.array(train_x), np.array(train_y), epochs=20)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 1s 6ms/step - loss: 1.4960 - accuracy: 0.5957
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3176 - accuracy: 0.5957
# Epoch 3/20
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1285 - accuracy: 0.6809
# Epoch 4/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9957 - accuracy: 0.7872
# Epoch 5/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8545 - accuracy: 0.8298
# Epoch 6/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7326 - accuracy: 0.8511
# Epoch 7/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6226 - accuracy: 0.8723
# Epoch 8/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5149 - accuracy: 0.9362
# Epoch 9/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4373 - accuracy: 0.9574
# Epoch 10/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3481 - accuracy: 0.9787
# Epoch 11/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2785 - accuracy: 0.9787
# Epoch 12/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2115 - accuracy: 0.9787
# Epoch 13/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1535 - accuracy: 0.9787
# Epoch 14/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1147 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0808 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 1.0000

# %%
# Train and Test accuracy
scores = best_model.evaluate(np.array(train_x), np.array(train_y))
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 0.0124 - accuracy: 1.0000
# Training Accuracy: 100.00%
